# %% [markdown]
# Looking for some examples on how to use docTR for OCR-related tasks? You've come to the right place 😀

# %% [markdown]
# # Installation
#
# Install all the dependencies to make the most out of docTR. The project provides two main [installation](https://mindee.github.io/doctr/latest/installing.html) streams: one for stable release, and developer mode.

# %% [markdown]
# ## Latest stable release
#
# This will install the last stable release that was published by our teams on pypi. It is expected to provide a clean and non-buggy experience for all users.

# %%
# TensorFlow
# !pip install python-doctr[tf]
# PyTorch
# !pip install python-doctr[torch]
# Restart runtime
exit()
# Out:
# Collecting python-doctr[torch]
#   Downloading python_doctr-0.6.0-py3-none-any.whl (239 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.3/239.3 kB 16.6 MB/s eta 0:00:00
# Collecting importlib-metadata (from python-doctr[torch])
#   Downloading importlib_metadata-6.8.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]) (1.22.4)
# Requirement already satisfied: scipy<2.0.0,>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]) (1.10.1)
# Requirement already satisfied: h5py<4.0.0,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]) (3.8.0)
# Requirement already satisfied: opencv-python<5.0.0,>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]) (4.7.0.72)
# Collecting pypdfium2<4.0.0,>=3.0.0 (from python-doctr[torch])
#   Downloading pypdfium2-3.21.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 53.4 MB/s eta 0:00:00
# Collecting pyclipper<2.0.0,>=1.2.0 (from python-doctr[torch])
#   Downloading pyclipper-1.3.0.post4-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (813 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 813.9/813.9 kB 49.3 MB/s eta 0:00:00
# Collecting shapely<2.0.0,>=1.6.0 (from python-doctr[torch])
#   Downloading Shapely-1.8.5.post1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 83.6 MB/s eta 0:00:00
# Collecting langdetect<2.0.0,>=1.0.9 (from python-doctr[torch])
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 68.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]) (3.7.1)
# Collecting weasyprint>=55.0 (from python-doctr[torch])
#   Downloading weasyprint-59.0-py3-none-any.whl (267 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.6/267.6 kB 28.2 MB/s eta 0:00:00
# Requirement already satisfied: Pillow>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]) (8.4.0)
# Requirement already satisfied: defusedxml>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]) (0.7.1)
# Collecting mplcursors>=0.3 (from python-doctr[torch])
#   Downloading mplcursors-0.5.2.tar.gz (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.0/89.0 kB 11.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting unidecode>=1.0.0 (from python-doctr[torch])
#   Downloading Unidecode-1.3.6-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.9/235.9 kB 26.6 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.30.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]) (4.65.0)
# Collecting rapidfuzz>=1.6.0 (from python-doctr[torch])
#   Downloading rapidfuzz-3.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 41.1 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0 (from python-doctr[torch])
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 19.5 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]) (2.0.1+cu118)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]) (0.15.2+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->python-doctr[torch]) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->python-doctr[torch]) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->python-doctr[torch]) (2.27.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->python-doctr[torch]) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->python-doctr[torch]) (4.7.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->python-doctr[torch]) (23.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from langdetect<2.0.0,>=1.0.9->python-doctr[torch]) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->python-doctr[torch]) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->python-doctr[torch]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->python-doctr[torch]) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->python-doctr[torch]) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->python-doctr[torch]) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->python-doctr[torch]) (2.8.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->python-doctr[torch]) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->python-doctr[torch]) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->python-doctr[torch]) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->python-doctr[torch]) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.0->python-doctr[torch]) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.0->python-doctr[torch]) (16.0.6)
# Collecting pydyf>=0.6.0 (from weasyprint>=55.0->python-doctr[torch])
#   Downloading pydyf-0.7.0-py3-none-any.whl (7.5 kB)
# Requirement already satisfied: cffi>=0.6 in /usr/local/lib/python3.10/dist-packages (from weasyprint>=55.0->python-doctr[torch]) (1.15.1)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from weasyprint>=55.0->python-doctr[torch]) (1.1)
# Requirement already satisfied: tinycss2>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from weasyprint>=55.0->python-doctr[torch]) (1.2.1)
# Collecting cssselect2>=0.1 (from weasyprint>=55.0->python-doctr[torch])
#   Downloading cssselect2-0.7.0-py3-none-any.whl (15 kB)
# Collecting Pyphen>=0.9.1 (from weasyprint>=55.0->python-doctr[torch])
#   Downloading pyphen-0.14.0-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 33.6 MB/s eta 0:00:00
# Collecting Pillow>=8.3.2 (from python-doctr[torch])
#   Downloading Pillow-10.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 52.6 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->python-doctr[torch]) (3.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=0.6->weasyprint>=55.0->python-doctr[torch]) (2.21)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from cssselect2>=0.1->weasyprint>=55.0->python-doctr[torch]) (0.5.1)
# Collecting zopfli>=0.1.4 (from fonttools>=4.22.0->matplotlib>=3.1.0->python-doctr[torch])
#   Downloading zopfli-0.2.2-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (848 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 848.9/848.9 kB 41.2 MB/s eta 0:00:00
# Collecting brotli>=1.0.1 (from fonttools>=4.22.0->matplotlib>=3.1.0->python-doctr[torch])
#   Downloading Brotli-1.0.9-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 48.7 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->python-doctr[torch]) (2.1.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->python-doctr[torch]) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->python-doctr[torch]) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->python-doctr[torch]) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->python-doctr[torch]) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->python-doctr[torch]) (1.3.0)
# Building wheels for collected packages: langdetect, mplcursors
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993224 sha256=f32aa823b368972dd80ef82f1f859dcba23fbfed826bc6c0295f9b74a365e310
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
#   Building wheel for mplcursors (setup.py) ... done
#   Created wheel for mplcursors: filename=mplcursors-0.5.2-py3-none-any.whl size=21054 sha256=d8b547ccf88fe6f1c1ad796b61de6657282d896de115488f61dc6716b78b481e
#   Stored in directory: /root/.cache/pip/wheels/b5/5b/fb/aed35cc15262c380536820fa3cb2e2d41fb52450de918a6785
# Successfully built langdetect mplcursors
# Installing collected packages: pyclipper, brotli, zopfli, unidecode, shapely, rapidfuzz, Pyphen, pypdfium2, pydyf, Pillow, langdetect, importlib-metadata, huggingface-hub, cssselect2, weasyprint, mplcursors, python-doctr
#   Attempting uninstall: shapely
#     Found existing installation: shapely 2.0.1
#     Uninstalling shapely-2.0.1:
#       Successfully uninstalled shapely-2.0.1
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 8.4.0
#     Uninstalling Pillow-8.4.0:
#       Successfully uninstalled Pillow-8.4.0
# Successfully installed Pillow-10.0.0 Pyphen-0.14.0 brotli-1.0.9 cssselect2-0.7.0 huggingface-hub-0.16.4 importlib-metadata-6.8.0 langdetect-1.0.9 mplcursors-0.5.2 pyclipper-1.3.0.post4 pydyf-0.7.0 pypdfium2-3.21.1 python-doctr-0.6.0 rapidfuzz-3.1.1 shapely-1.8.5.post1 unidecode-1.3.6 weasyprint-59.0 zopfli-0.2.2

# %% [markdown]
# ## From source
#
# Before being staged for a stable release, we constantly iterate on the community feedback to improve the library. Bug fixes and performance improvements are regularly pushed to the project Git repository. Using this installation method, you will access all the latest features that have not yet made their way to a pypi release!

# %%
# Colab related installations to install pyproject.toml projects correctly
# !sudo apt install libcairo2-dev pkg-config
# !pip3 install pycairo
# Install the most up-to-date version from GitHub
# TensorFlow
# !pip install python-doctr[tf]@git+https://github.com/mindee/doctr.git
# PyTorch
# !pip3 install python-doctr[torch]@git+https://github.com/mindee/doctr.git
# Restart runtime
exit()
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# pkg-config is already the newest version (0.29.1-0ubuntu4).
# The following additional packages will be installed:
#   libblkid-dev libblkid1 libcairo-script-interpreter2 libffi-dev
#   libglib2.0-dev libglib2.0-dev-bin liblzo2-2 libmount-dev libmount1
#   libpixman-1-dev libselinux1-dev libsepol1-dev libxcb-render0-dev
#   libxcb-shm0-dev
# Suggested packages:
#   libcairo2-doc libgirepository1.0-dev libglib2.0-doc libgdk-pixbuf2.0-bin
#   | libgdk-pixbuf2.0-dev libxml2-utils
# The following NEW packages will be installed:
#   libblkid-dev libcairo-script-interpreter2 libcairo2-dev libffi-dev
#   libglib2.0-dev libglib2.0-dev-bin liblzo2-2 libmount-dev libpixman-1-dev
#   libselinux1-dev libsepol1-dev libxcb-render0-dev libxcb-shm0-dev
# The following packages will be upgraded:
#   libblkid1 libmount1
# 2 upgraded, 13 newly installed, 0 to remove and 13 not upgraded.
# Need to get 3,779 kB of archives.
# After this operation, 20.0 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libblkid1 amd64 2.34-0.1ubuntu9.4 [137 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libmount1 amd64 2.34-0.1ubuntu9.4 [150 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/main amd64 liblzo2-2 amd64 2.10-2 [50.8 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/main amd64 libcairo-script-interpreter2 amd64 1.16.0-4ubuntu1 [54.2 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libpixman-1-dev amd64 0.38.4-0ubuntu2.1 [243 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcb-render0-dev amd64 1.14-2 [18.4 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcb-shm0-dev amd64 1.14-2 [6,716 B]
# Get:8 http://archive.ubuntu.com/ubuntu focal/main amd64 libffi-dev amd64 3.3-4 [57.0 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libglib2.0-dev-bin amd64 2.64.6-1~ubuntu20.04.6 [109 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libblkid-dev amd64 2.34-0.1ubuntu9.4 [167 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libmount-dev amd64 2.34-0.1ubuntu9.4 [177 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libsepol1-dev amd64 3.0-1ubuntu0.1 [325 kB]
# Get:13 http://archive.ubuntu.com/ubuntu focal/main amd64 libselinux1-dev amd64 3.0-1build2 [151 kB]
# Get:14 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libglib2.0-dev amd64 2.64.6-1~ubuntu20.04.6 [1,507 kB]
# Get:15 http://archive.ubuntu.com/ubuntu focal/main amd64 libcairo2-dev amd64 1.16.0-4ubuntu1 [627 kB]
# Fetched 3,779 kB in 0s (13.6 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 15.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# (Reading database ... 123105 files and directories currently installed.)
# Preparing to unpack .../libblkid1_2.34-0.1ubuntu9.4_amd64.deb ...
# Unpacking libblkid1:amd64 (2.34-0.1ubuntu9.4) over (2.34-0.1ubuntu9.3) ...
# Setting up libblkid1:amd64 (2.34-0.1ubuntu9.4) ...
# (Reading database ... 123105 files and directories currently installed.)
# Preparing to unpack .../libmount1_2.34-0.1ubuntu9.4_amd64.deb ...
# Unpacking libmount1:amd64 (2.34-0.1ubuntu9.4) over (2.34-0.1ubuntu9.3) ...
# Setting up libmount1:amd64 (2.34-0.1ubuntu9.4) ...
# Selecting previously unselected package liblzo2-2:amd64.
# (Reading database ... 123105 files and directories currently installed.)
# Preparing to unpack .../00-liblzo2-2_2.10-2_amd64.deb ...
# Unpacking liblzo2-2:amd64 (2.10-2) ...
# Selecting previously unselected package libcairo-script-interpreter2:amd64.
# Preparing to unpack .../01-libcairo-script-interpreter2_1.16.0-4ubuntu1_amd64.deb ...
# Unpacking libcairo-script-interpreter2:amd64 (1.16.0-4ubuntu1) ...
# Selecting previously unselected package libpixman-1-dev:amd64.
# Preparing to unpack .../02-libpixman-1-dev_0.38.4-0ubuntu2.1_amd64.deb ...
# Unpacking libpixman-1-dev:amd64 (0.38.4-0ubuntu2.1) ...
# Selecting previously unselected package libxcb-render0-dev:amd64.
# Preparing to unpack .../03-libxcb-render0-dev_1.14-2_amd64.deb ...
# Unpacking libxcb-render0-dev:amd64 (1.14-2) ...
# Selecting previously unselected package libxcb-shm0-dev:amd64.
# Preparing to unpack .../04-libxcb-shm0-dev_1.14-2_amd64.deb ...
# Unpacking libxcb-shm0-dev:amd64 (1.14-2) ...
# Selecting previously unselected package libffi-dev:amd64.
# Preparing to unpack .../05-libffi-dev_3.3-4_amd64.deb ...
# Unpacking libffi-dev:amd64 (3.3-4) ...
# Selecting previously unselected package libglib2.0-dev-bin.
# Preparing to unpack .../06-libglib2.0-dev-bin_2.64.6-1~ubuntu20.04.6_amd64.deb ...
# Unpacking libglib2.0-dev-bin (2.64.6-1~ubuntu20.04.6) ...
# Selecting previously unselected package libblkid-dev:amd64.
# Preparing to unpack .../07-libblkid-dev_2.34-0.1ubuntu9.4_amd64.deb ...
# Unpacking libblkid-dev:amd64 (2.34-0.1ubuntu9.4) ...
# Selecting previously unselected package libmount-dev:amd64.
# Preparing to unpack .../08-libmount-dev_2.34-0.1ubuntu9.4_amd64.deb ...
# Unpacking libmount-dev:amd64 (2.34-0.1ubuntu9.4) ...
# Selecting previously unselected package libsepol1-dev:amd64.
# Preparing to unpack .../09-libsepol1-dev_3.0-1ubuntu0.1_amd64.deb ...
# Unpacking libsepol1-dev:amd64 (3.0-1ubuntu0.1) ...
# Selecting previously unselected package libselinux1-dev:amd64.
# Preparing to unpack .../10-libselinux1-dev_3.0-1build2_amd64.deb ...
# Unpacking libselinux1-dev:amd64 (3.0-1build2) ...
# Selecting previously unselected package libglib2.0-dev:amd64.
# Preparing to unpack .../11-libglib2.0-dev_2.64.6-1~ubuntu20.04.6_amd64.deb ...
# Unpacking libglib2.0-dev:amd64 (2.64.6-1~ubuntu20.04.6) ...
# Selecting previously unselected package libcairo2-dev:amd64.
# Preparing to unpack .../12-libcairo2-dev_1.16.0-4ubuntu1_amd64.deb ...
# Unpacking libcairo2-dev:amd64 (1.16.0-4ubuntu1) ...
# Setting up libglib2.0-dev-bin (2.64.6-1~ubuntu20.04.6) ...
# Setting up libblkid-dev:amd64 (2.34-0.1ubuntu9.4) ...
# Setting up libpixman-1-dev:amd64 (0.38.4-0ubuntu2.1) ...
# Setting up libsepol1-dev:amd64 (3.0-1ubuntu0.1) ...
# Setting up liblzo2-2:amd64 (2.10-2) ...
# Setting up libffi-dev:amd64 (3.3-4) ...
# Setting up libxcb-shm0-dev:amd64 (1.14-2) ...
# Setting up libxcb-render0-dev:amd64 (1.14-2) ...
# Setting up libmount-dev:amd64 (2.34-0.1ubuntu9.4) ...
# Setting up libcairo-script-interpreter2:amd64 (1.16.0-4ubuntu1) ...
# Setting up libselinux1-dev:amd64 (3.0-1build2) ...
# Setting up libglib2.0-dev:amd64 (2.64.6-1~ubuntu20.04.6) ...
# Processing triggers for libglib2.0-0:amd64 (2.64.6-1~ubuntu20.04.6) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Processing triggers for man-db (2.9.1-1) ...
# Setting up libcairo2-dev:amd64 (1.16.0-4ubuntu1) ...
# Collecting pycairo
#   Downloading pycairo-1.24.0.tar.gz (344 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 344.9/344.9 kB 18.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: pycairo
#   Building wheel for pycairo (pyproject.toml) ... done
#   Created wheel for pycairo: filename=pycairo-1.24.0-cp310-cp310-linux_x86_64.whl size=331630 sha256=b9340137dd0cdb40f9c0741bfade48bc22a0eb75bfc3ce8a11394b40e2068d1e
#   Stored in directory: /root/.cache/pip/wheels/42/f6/f8/ad6377458a0a8eea738a091a499ca95d020c87e76d5d1dd6f5
# Successfully built pycairo
# Installing collected packages: pycairo
# Successfully installed pycairo-1.24.0
# Collecting python-doctr[torch]@ git+https://github.com/mindee/doctr.git
#   Cloning https://github.com/mindee/doctr.git to /tmp/pip-install-we8sag5o/python-doctr_58a1870f79f94b538da761dadb4c70e2
#   Running command git clone --filter=blob:none --quiet https://github.com/mindee/doctr.git /tmp/pip-install-we8sag5o/python-doctr_58a1870f79f94b538da761dadb4c70e2
#   Resolved https://github.com/mindee/doctr.git to commit d0b67e5cca6655e6f094e10554bb9952073a0ff4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (6.8.0)
# Requirement already satisfied: numpy<2.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (1.22.4)
# Requirement already satisfied: scipy<2.0.0,>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (1.10.1)
# Requirement already satisfied: h5py<4.0.0,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (3.8.0)
# Requirement already satisfied: opencv-python<5.0.0,>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (4.7.0.72)
# Collecting pypdfium2<5.0.0,>=4.0.0 (from python-doctr[torch]@ git+https://github.com/mindee/doctr.git)
#   Downloading pypdfium2-4.18.0-py3-none-manylinux_2_17_x86_64.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 57.6 MB/s eta 0:00:00
# Requirement already satisfied: pyclipper<2.0.0,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (1.3.0.post4)
# Requirement already satisfied: shapely<3.0.0,>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (1.8.5.post1)
# Requirement already satisfied: langdetect<2.0.0,>=1.0.9 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (1.0.9)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (3.1.1)
# Requirement already satisfied: matplotlib>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (3.7.1)
# Requirement already satisfied: weasyprint>=55.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (59.0)
# Requirement already satisfied: Pillow>=10.0.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (10.0.0)
# Requirement already satisfied: defusedxml>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (0.7.1)
# Requirement already satisfied: mplcursors>=0.3 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (0.5.2)
# Requirement already satisfied: unidecode>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (1.3.6)
# Requirement already satisfied: tqdm>=4.30.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (4.65.0)
# Requirement already satisfied: huggingface-hub>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (0.16.4)
# Requirement already satisfied: torch<3.0.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (2.0.1+cu118)
# Requirement already satisfied: torchvision>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (0.15.2+cu118)
# Collecting onnx<3.0.0,>=1.12.0 (from python-doctr[torch]@ git+https://github.com/mindee/doctr.git)
#   Downloading onnx-1.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 66.4 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.5.0->python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.5.0->python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.5.0->python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (2.27.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.5.0->python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.5.0->python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (4.7.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.5.0->python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (23.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from langdetect<2.0.0,>=1.0.9->python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (2.8.2)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from onnx<3.0.0,>=1.12.0->python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=1.12.0->python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=1.12.0->python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=1.12.0->python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=1.12.0->python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch<3.0.0,>=1.12.0->python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch<3.0.0,>=1.12.0->python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (16.0.6)
# Requirement already satisfied: pydyf>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from weasyprint>=55.0->python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (0.7.0)
# Requirement already satisfied: cffi>=0.6 in /usr/local/lib/python3.10/dist-packages (from weasyprint>=55.0->python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (1.15.1)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from weasyprint>=55.0->python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (1.1)
# Requirement already satisfied: tinycss2>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from weasyprint>=55.0->python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (1.2.1)
# Requirement already satisfied: cssselect2>=0.1 in /usr/local/lib/python3.10/dist-packages (from weasyprint>=55.0->python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (0.7.0)
# Requirement already satisfied: Pyphen>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from weasyprint>=55.0->python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (3.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=0.6->weasyprint>=55.0->python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (2.21)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from cssselect2>=0.1->weasyprint>=55.0->python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (0.5.1)
# Requirement already satisfied: zopfli>=0.1.4 in /usr/local/lib/python3.10/dist-packages (from fonttools>=4.22.0->matplotlib>=3.1.0->python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (0.2.2)
# Requirement already satisfied: brotli>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from fonttools>=4.22.0->matplotlib>=3.1.0->python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (1.0.9)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch<3.0.0,>=1.12.0->python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (2.1.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.5.0->python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.5.0->python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.5.0->python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.5.0->python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch<3.0.0,>=1.12.0->python-doctr[torch]@ git+https://github.com/mindee/doctr.git) (1.3.0)
# Building wheels for collected packages: python-doctr
#   Building wheel for python-doctr (pyproject.toml) ... done
#   Created wheel for python-doctr: filename=python_doctr-0.6.1a0-py3-none-any.whl size=263906 sha256=ab48a8963007b648711533e4386caa06484dce8e3427e0555c7de44b52702640
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nf83uqsk/wheels/1e/6c/6b/37a5d1591cd372f8244089332dcb4ea90096822d6f76103b21
# Successfully built python-doctr
# Installing collected packages: pypdfium2, onnx, python-doctr
#   Attempting uninstall: pypdfium2
#     Found existing installation: pypdfium2 3.21.1
#     Uninstalling pypdfium2-3.21.1:
#       Successfully uninstalled pypdfium2-3.21.1
#   Attempting uninstall: python-doctr
#     Found existing installation: python-doctr 0.6.0
#     Uninstalling python-doctr-0.6.0:
#       Successfully uninstalled python-doctr-0.6.0
# Successfully installed onnx-1.14.0 pypdfium2-4.18.0 python-doctr-0.6.1a0

# %% [markdown]
# Now go to  `Runtime/Restart runtime` for your changes to take effect!

# %% [markdown]
# # Basic usage
#
# We're going to review the main features of docTR 🎁
# And for you to have a proper overview of its capabilities, we will need some free fonts for a proper output visualization:

# %%
# Install some free fonts for result rendering
# !sudo apt-get install fonts-freefont-ttf -y

# %% [markdown]
# Let's take care of all the imports directly

# %%
# %matplotlib inline
import os

# Let's pick the desired backend
# os.environ['USE_TF'] = '1'
os.environ['USE_TORCH'] = '1'

import matplotlib.pyplot as plt

from doctr.io import DocumentFile
from doctr.models import ocr_predictor

# %% [markdown]
# For the next steps, we will need a proper PDF document that will be used to showcase the library features

# %%
# Download a sample
#!wget https://eforms.com/download/2019/01/Cash-Payment-Receipt-Template.pdf
# Read the file
doc = DocumentFile.from_images("img.jpg")
print(f"Number of pages: {len(doc)}")
# Out:
# Number of pages: 1

# %% [markdown]
# docTR is, under the hood, running Deep Learning models to perform the different tasks it supports. Those models were built and trained with very popular frameworks for maximum compatibility (you will be pleased to know that you can switch from [PyTorch](https://pytorch.org/) to [TensorFlow](https://www.tensorflow.org/) without noticing any difference for you). By default, our high-level API sets the best default values so that you get high performing models without having to know anything about it. All of this is wrapper in a `Predictor` object, which will take care of pre-processing, model inference and post-processing for you ⚡
#
# Let's instantiate one!

# %%
# Instantiate a pretrained model
predictor = ocr_predictor(pretrained=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:135: UserWarning: Using 'weights' as positional parameter(s) is deprecated since 0.13 and may be removed in the future. Please use keyword parameter(s) instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Downloading https://doctr-static.mindee.com/models?id=v0.3.1/db_resnet50-ac60cadc.pt&src=0 to /root/.cache/doctr/models/db_resnet50-ac60cadc.pt
#   0%|          | 0/101971449 [00:00<?, ?it/s]
# Downloading https://doctr-static.mindee.com/models?id=v0.3.1/crnn_vgg16_bn-9762b0b0.pt&src=0 to /root/.cache/doctr/models/crnn_vgg16_bn-9762b0b0.pt
#   0%|          | 0/63286381 [00:00<?, ?it/s]

# %% [markdown]
# By default, PyTorch model provides a nice visual description of a model, which is handy when it comes to debugging or knowing what you just created. We also added a similar feature for TensorFlow backend so that you don't miss on this nice assistance.
#
# Let's dive into this model 🕵

# %%
# Display the architecture
print(predictor)

# %% [markdown]
# Here we are inspecting the most complex (and high-level) object of docTR API: an OCR predictor. Since docTR achieves Optical Character Recognition by first localizing textual elements (Text Detection), then extracting the corresponding text from each location (Text Recognition), the OCR Predictor wraps two sub-predictors: one for text detection, and the other for text recognition.

# %% [markdown]
# ## Basic inference
#
# It looks quite complex, isn't it?
# Well that will not prevent you from easily get nice results. See for yourself:

# %%
result = predictor(doc)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(

# %% [markdown]
# ## Prediction visualization
#
# If you rightfully prefer to see the results with your eyes, docTR includes a few visualization features. We will first overlay our predictions on the original document:

# %%
result.show(doc)

# %%
result
# Out:
# Document(
#   (pages): [Page(
#     dimensions=(576, 531)
#     (blocks): [
#       Block(
#         (lines): [Line(
#           (words): [
#             Word(value='SAP', confidence=0.65),
#             Word(value='CODE:', confidence=0.51),
#             Word(value=':', confidence=1.0),
#             Word(value='IMFCPO3', confidence=0.52),
#           ]
#         )]
#         (artefacts): []
#       ),
#       Block(
#         (lines): [Line(
#           (words): [Word(value='Amulspray', confidence=0.83)]
#         )]
#         (artefacts): []
#       ),
#       Block(
#         (lines): [Line(
#           (words): [
#             Word(value='SAP', confidence=1.0),
#             Word(value='CODE', confidence=0.99),
#             Word(value=':', confidence=0.79),
#             Word(value='IMFCP03', confidence=0.53),
#           ]
#         )]
#         (artefacts): []
#       ),
#       Block(
#         (lines): [
#           Line(
#             (words): [
#               Word(value='INFANT', confidence=1.0),
#               Word(value='MILK', confidence=1.0),
#               Word(value='FOOD', confidence=0.96),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='INFANT', confidence=0.99),
#               Word(value='MILK', confidence=0.97),
#               Word(value='SUBSTITUTE', confidence=0.64),
#             ]
#           ),
#         ]
#         (artefacts): []
#       ),
#       Block(
#         (lines): [Line(
#           (words): [
#             Word(value='24', confidence=1.0),
#             Word(value='Pieces', confidence=1.0),
#             Word(value='X', confidence=0.93),
#             Word(value='500', confidence=1.0),
#             Word(value='9', confidence=0.95),
#             Word(value='Pouch', confidence=0.99),
#           ]
#         )]
#         (artefacts): []
#       ),
#     ]
#   )]
# )

# %% [markdown]
# Looks accurate!
# But we can go further: if the extracted information is correctly structured, we should be able to recreate the page entirely. So let's do this 🎨

# %%
synthetic_pages = result.synthesize()
plt.imshow(synthetic_pages[0]); plt.axis('off'); plt.show()
# Out:
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.

# %% [markdown]
# ## Exporting results
#
# OK, so the predictions are relevant, but how would you integrate this into your own document processing pipeline? Perhaps you're not using Python at all?
#
# Well, if you happen to be using JSON or XML exports, they are already supported 🤗

# %%
# JSON export
json_export = result.export()
print(json_export)
# Out:
# {'pages': [{'page_idx': 0, 'dimensions': (576, 531), 'orientation': {'value': None, 'confidence': None}, 'language': {'value': None, 'confidence': None}, 'blocks': [{'geometry': ((0.2724609375, 0.0078125), (0.4716796875, 0.0302734375)), 'lines': [{'geometry': ((0.2724609375, 0.0078125), (0.4716796875, 0.0302734375)), 'words': [{'value': 'SAP', 'confidence': 0.6465551853179932, 'geometry': ((0.2724609375, 0.0078125), (0.318359375, 0.0302734375))}, {'value': 'CODE:', 'confidence': 0.5098241567611694, 'geometry': ((0.3193359375, 0.0087890625), (0.3837890625, 0.02734375))}, {'value': ':', 'confidence': 0.999958872795105, 'geometry': ((0.3759765625, 0.0107421875), (0.3916015625, 0.0244140625))}, {'value': 'IMFCPO3', 'confidence': 0.5184717774391174, 'geometry': ((0.3896484375, 0.0087890625), (0.4716796875, 0.0263671875))}]}], 'artefacts': []}, {'geometry': ((0.0703125, 0.259765625), (0.5458984375, 0.3583984375)), 'lines': [{'geometry': ((0.0703125, 0.259765625), (0.5458984375, 0.3583984375)), 'words': [{'value': 'Amulspray', 'confidence': 0.8284239172935486, 'geometry': ((0.0703125, 0.259765625), (0.5458984375, 0.3583984375))}]}], 'artefacts': []}, {'geometry': ((0.7783203125, 0.294921875), (0.9765625, 0.318359375)), 'lines': [{'geometry': ((0.7783203125, 0.294921875), (0.9765625, 0.318359375)), 'words': [{'value': 'SAP', 'confidence': 0.9985755681991577, 'geometry': ((0.7783203125, 0.2958984375), (0.82421875, 0.318359375))}, {'value': 'CODE', 'confidence': 0.9891178011894226, 'geometry': ((0.822265625, 0.2958984375), (0.8828125, 0.3173828125))}, {'value': ':', 'confidence': 0.793541431427002, 'geometry': ((0.880859375, 0.2958984375), (0.8994140625, 0.3173828125))}, {'value': 'IMFCP03', 'confidence': 0.5348619818687439, 'geometry': ((0.8916015625, 0.294921875), (0.9765625, 0.31640625))}]}], 'artefacts': []}, {'geometry': ((0.125, 0.3623046875), (0.494140625, 0.419921875)), 'lines': [{'geometry': ((0.171875, 0.3623046875), (0.447265625, 0.3876953125)), 'words': [{'value': 'INFANT', 'confidence': 0.998195469379425, 'geometry': ((0.171875, 0.3662109375), (0.2802734375, 0.3876953125))}, {'value': 'MILK', 'confidence': 0.9976491332054138, 'geometry': ((0.2861328125, 0.36328125), (0.361328125, 0.3857421875))}, {'value': 'FOOD', 'confidence': 0.9631388187408447, 'geometry': ((0.3662109375, 0.3623046875), (0.447265625, 0.3837890625))}]}, {'geometry': ((0.125, 0.3935546875), (0.494140625, 0.419921875)), 'words': [{'value': 'INFANT', 'confidence': 0.9903760552406311, 'geometry': ((0.125, 0.3984375), (0.23046875, 0.419921875))}, {'value': 'MILK', 'confidence': 0.9689831137657166, 'geometry': ((0.236328125, 0.3955078125), (0.3095703125, 0.41796875))}, {'value': 'SUBSTITUTE', 'confidence': 0.6430258750915527, 'geometry': ((0.31640625, 0.3935546875), (0.494140625, 0.4150390625))}]}], 'artefacts': []}, {'geometry': ((0.1259765625, 0.7275390625), (0.513671875, 0.7666015625)), 'lines': [{'geometry': ((0.1259765625, 0.7275390625), (0.513671875, 0.7666015625)), 'words': [{'value': '24', 'confidence': 0.9998990297317505, 'geometry': ((0.1259765625, 0.7353515625), (0.1728515625, 0.7666015625))}, {'value': 'Pieces', 'confidence': 0.9993195533752441, 'geometry': ((0.17578125, 0.7333984375), (0.2841796875, 0.7646484375))}, {'value': 'X', 'confidence': 0.9313101172447205, 'geometry': ((0.28515625, 0.7294921875), (0.3173828125, 0.7626953125))}, {'value': '500', 'confidence': 0.9959386587142944, 'geometry': ((0.31640625, 0.73046875), (0.3779296875, 0.76171875))}, {'value': '9', 'confidence': 0.9473692774772644, 'geometry': ((0.3818359375, 0.7333984375), (0.408203125, 0.763671875))}, {'value': 'Pouch', 'confidence': 0.9903490543365479, 'geometry': ((0.4130859375, 0.7275390625), (0.513671875, 0.7568359375))}]}], 'artefacts': []}]}]}

# %%
# XML export
xml_output = result.export_as_xml()
print(xml_output[0][0])
# Out:
# b'<html xmlns="http://www.w3.org/1999/xhtml" xml:lang="en"><head><title>docTR - XML export (hOCR)</title><meta http-equiv="Content-Type" content="text/html; charset=utf-8" /><meta name="ocr-system" content="python-doctr 0.6.1a0" /><meta name="ocr-capabilities" content="ocr_page ocr_carea ocr_par ocr_line ocrx_word" /></head><body><div class="ocr_page" id="page_1" title="image; bbox 0 0 531 576; ppageno 0" /><div class="ocr_carea" id="block_1" title="bbox 145 4                     250 17"><p class="ocr_par" id="par_1" title="bbox 145 4                     250 17"><span class="ocr_line" id="line_1" title="bbox 145 4                         250 17;                         baseline 0 0; x_size 0; x_descenders 0; x_ascenders 0"><span class="ocrx_word" id="word_1" title="bbox 145 4                             169 17;                             x_wconf 65">SAP</span><span class="ocrx_word" id="word_2" title="bbox 170 5                             204 16;                             x_wconf 51">CODE:</span><span class="ocrx_word" id="word_3" title="bbox 200 6                             208 14;                             x_wconf 100">:</span><span class="ocrx_word" id="word_4" title="bbox 207 5                             250 15;                             x_wconf 52">IMFCPO3</span></span></p></div><div class="ocr_carea" id="block_2" title="bbox 37 150                     290 206"><p class="ocr_par" id="par_2" title="bbox 37 150                     290 206"><span class="ocr_line" id="line_2" title="bbox 37 150                         290 206;                         baseline 0 0; x_size 0; x_descenders 0; x_ascenders 0"><span class="ocrx_word" id="word_5" title="bbox 37 150                             290 206;                             x_wconf 83">Amulspray</span></span></p></div><div class="ocr_carea" id="block_3" title="bbox 413 170                     519 183"><p class="ocr_par" id="par_3" title="bbox 413 170                     519 183"><span class="ocr_line" id="line_3" title="bbox 413 170                         519 183;                         baseline 0 0; x_size 0; x_descenders 0; x_ascenders 0"><span class="ocrx_word" id="word_6" title="bbox 413 170                             438 183;                             x_wconf 100">SAP</span><span class="ocrx_word" id="word_7" title="bbox 437 170                             469 183;                             x_wconf 99">CODE</span><span class="ocrx_word" id="word_8" title="bbox 468 170                             478 183;                             x_wconf 79">:</span><span class="ocrx_word" id="word_9" title="bbox 473 170                             519 182;                             x_wconf 53">IMFCP03</span></span></p></div><div class="ocr_carea" id="block_4" title="bbox 66 209                     262 242"><p class="ocr_par" id="par_4" title="bbox 66 209                     262 242"><span class="ocr_line" id="line_4" title="bbox 91 209                         237 223;                         baseline 0 0; x_size 0; x_descenders 0; x_ascenders 0"><span class="ocrx_word" id="word_10" title="bbox 91 211                             149 223;                             x_wconf 100">INFANT</span><span class="ocrx_word" id="word_11" title="bbox 152 209                             192 222;                             x_wconf 100">MILK</span><span class="ocrx_word" id="word_12" title="bbox 194 209                             237 221;                             x_wconf 96">FOOD</span></span><span class="ocr_line" id="line_5" title="bbox 66 227                         262 242;                         baseline 0 0; x_size 0; x_descenders 0; x_ascenders 0"><span class="ocrx_word" id="word_13" title="bbox 66 230                             122 242;                             x_wconf 99">INFANT</span><span class="ocrx_word" id="word_14" title="bbox 125 228                             164 241;                             x_wconf 97">MILK</span><span class="ocrx_word" id="word_15" t ...

# %% [markdown]
# # Another Image

# %%
doc = DocumentFile.from_images("img2.jpg")
result = predictor(doc)
result.show(doc)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(

# %%
doc = DocumentFile.from_images("/content/IMG-20230709-WA0013.jpg")
result = predictor(doc)
result.show(doc)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
synthetic_pages = result.synthesize()
plt.imshow(synthetic_pages[0]); plt.axis('off'); plt.show()
# Out:
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
# WARNING:root:unable to load recommended font family. Loading default PIL font,font size issues may be expected.To prevent this, it is recommended to specify the value of 'font_family'.
